# %% [markdown]
# # Cortexbias\n\nPhase 2 notebook walkthrough.

# %%
import pandas as pd\nfrom cortexbias import CortexbiasCalculator\n

# %%
df = pd.read_csv("cortexbias_dataset.csv")\ndf.head()\n

# %%
calc = CortexbiasCalculator()\nresult = calc.calculate_cortexbias(df)\nresult.head()\n

# %%
result["cortexbias_index"].describe()\n

# %%
result.groupby("cortexbias_band").size()\n

# %%
result["cortexbias_index"].hist(bins=20)\n

# %% [markdown]
# Interpretation: `Cortexbias` index is now ready for stress testing.
